# %% [markdown]
# Filtering and Ordering With Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\lucas\Documents\Projects\Python\Data Analysis with Pandas & Python\world_population_excel_workbook.xlsx")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df [df['Rank']<= 10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16         171186372        167420951        157830000        148391139
# 27         215313498        213196304        205188205        196353492
# ...

# %%
specific_countries = ['Bangladesh','Brazil']
df [df['Country'].isin(specific_countries)]
# Out:
#     Rank CCA3     Country   Capital      Continent  2022 Population  \
# 16     8  BGD  Bangladesh     Dhaka           Asia        171186372
# 27     7  BRA      Brazil  Brasilia  South America        215313498
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16        167420951        157830000        148391139        129193327
# 27        213196304        205188205        196353492        175873720
#
#     1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# 16        107147651         83929765         67541860       147570
# 27        150706446        122288383         96369875      8515767
#
#     Density (per kmÂ²)  Growth Rate  World Population Percentage
# 16           1160.0350       1.0108                         2.15
# 27             25.2841       1.0046                         2.70

# %%
df [df['Country'].str.contains('New')]
# Out:
#      Rank CCA3           Country       Capital Continent  2022 Population  \
# 145   185  NCL     New Caledonia       NoumÃ©a   Oceania           289950
# 146   123  NZL       New Zealand    Wellington   Oceania          5185288
# 160    93  PNG  Papua New Guinea  Port Moresby   Oceania         10142619
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 145           286403           283032           261426           221537
# 146          5061133          4590590          4346338          3855266
# 160          9749640          8682174          7583269          5508297
#
#      1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# 145           177264           148599           110982        18575
# 146          3397389          3147168          2824061       270467
# 160          3864972          3104788          2489059       462840
#
#      Density (per kmÂ²)  Growth Rate  World Population Percentage
# ...

# %%
df2 = df.set_index('Country')
df2

# %%
df2.filter(items = ['Continent','CCA3'], axis=1)
# Out:
#                   Continent CCA3
# Country
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Zimbabwe'], axis=0)
# Out:
#           Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Zimbabwe    74  ZWE  Harare    Africa         16320537         15669666
#
#           2015 Population  2010 Population  2000 Population  1990 Population  \
# Zimbabwe         14154937         12839771         11834676         10113893
#
#           1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# Zimbabwe          7049926          5202918       390757             41.7665
#
#           Growth Rate  World Population Percentage
# Zimbabwe       1.0204                          0.2

# %%
df2.filter(like = 'New', axis=0)
# Out:
#                   Rank CCA3       Capital Continent  2022 Population  \
# Country
# New Caledonia      185  NCL       NoumÃ©a   Oceania           289950
# New Zealand        123  NZL    Wellington   Oceania          5185288
# Papua New Guinea    93  PNG  Port Moresby   Oceania         10142619
#
#                   2020 Population  2015 Population  2010 Population  \
# Country
# New Caledonia              286403           283032           261426
# New Zealand               5061133          4590590          4346338
# Papua New Guinea          9749640          8682174          7583269
#
#                   2000 Population  1990 Population  1980 Population  \
# Country
# New Caledonia              221537           177264           148599
# New Zealand               3855266          3397389          3147168
# Papua New Guinea          5508297          3864972          3104788
#
#                   1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# Country
# ...

# %%
df2.loc['United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                       338289857
# 2020 Population                       335942003
# 2015 Population                       324607776
# 2010 Population                       311182845
# 2000 Population                       282398554
# 1990 Population                       248083732
# 1980 Population                       223140018
# 1970 Population                       200328340
# Area (kmÂ²)                             9372610
# Density (per kmÂ²)                      36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[15]
# Out:
# Rank                                 154
# CCA3                                 BHR
# Capital                           Manama
# Continent                           Asia
# 2022 Population                  1472233
# 2020 Population                  1477469
# 2015 Population                  1362142
# 2010 Population                  1213645
# 2000 Population                   711442
# 1990 Population                   517418
# 1980 Population                   362595
# 1970 Population                   222555
# Area (kmÂ²)                          765
# Density (per kmÂ²)             1924.4876
# Growth Rate                       1.0061
# World Population Percentage         0.02
# Name: Bahrain, dtype: object

# %%
df[ df ['Rank'] < 10].sort_values(by = 'Rank',ascending = True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# ...
